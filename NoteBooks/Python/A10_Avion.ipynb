# %% [markdown]
# # Programacion I
# Este caso de estudio tiene como objetivo la aplicación de la metodología para desarrollo de programas utilizando python como lenguaje de programación, este ejercicio esta basado en los ejercicios propuestos por el protecto Cupi2 de la Universidad de los Andes Tomado de  [Link][1]
#
# [1]: https://cupi2.virtual.uniandes.edu.co/

# %% [markdown]
# # (1) Especificación del Problema
# ## El Avion
#
# Basado en este ejercicio  [Link][1]
#
#
# Se quiere crear un programa que tenga como objetivo el manejo de reservas de un avión. Este avión cuenta con un número establecido de sillas que se clasifican en Ejecutivas y EconomicaS. Cada silla puede ser asignada a un pasajero solo con su numero de cedula. Este dato es la entrada principal para poder consultar una reserva
# o eliminarla del sistema.
# Cuando se asigna una silla es necesario conocer las preferencias del usuario. Este puede
# elegir la posición de la silla, ventana, pasillo o centro, y la clase, ejecutiva o económica. En el
# caso especial de las sillas ejecutivas, solo es posible elegir las posiciones: ventana o pasillo.
# Las sillas son asignadas de forma secuencial según su ubicación y su clase. De igual forma, el
# programa permite buscar la reserva de un pasajero y visualizar los datos de la reserva.
# [1]:https://cupi2.virtual.uniandes.edu.co/nivel-3/casos-de-estudio/el-avion
#
#
# El programa debe permitir:
# 1. Crear un avion
# 2. Listar las sillas del avion
# 3. Asignar una silla a un pasajero
# 4. Eliminar reserva
# 5. Buscar pasajero
# 6. Calcular el porcentaje de ocupación del avión.

# %% [markdown]
# ## (2) Analisis: Lista de Requisitos Funcionales
# El programa debe permitir:
#     - R1. Crear un avion
#     - R2. Listar las Sillas del Avión
#     - R3. Asignar una silla a un pasajero
#     - R4. Eliminar reserva
#     - R5. Buscar pasajero
#     - R6. Calcular el porcentaje de ocupación del avión.

# %% [markdown]
# ## (3) Analisis: Datos del Problema
#
# #### Silla
#     - numero
#     - clase
#     - ubicacion
#     - pasajero
# #### Avion
#     Lista de sillas

# %% [markdown]
# ## (4) Analisis: Especificacion Requisitos
#
# <style>
# .tg  {border-collapse:collapse;border-spacing:0;border-color:#aaa;}
# .tg td{font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#aaa;color:#333;background-color:#fff;}
# .tg th{font-family:Arial, sans-serif;font-size:14px;font-weight:normal;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#aaa;color:#fff;background-color:#f38630;}
# .tg .tg-1wig{font-weight:bold;text-align:left;vertical-align:top}
# .tg .tg-gcmg{font-weight:bold;background-color:#f8a102;text-align:left}
# .tg .tg-4qtd{font-weight:bold;background-color:#f8a102;text-align:left;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
#   <tbody><tr>
#     <th class="tg-gcmg">Nombre</th>
#     <th class="tg-4qtd">R1: Crear un avion</th>
#   </tr>
#   <tr>
#     <td class="tg-1wig">Resumen</td>
#     <td class="tg-0lax">Crea la lista de sillas para el avion  de acuerdo a las caracteristicas dadas</td>
#   </tr>
#   <tr>
#     <td class="tg-1wig">Entradas</td>
#     <td class="tg-0lax">numero de filas ejecutivas y numero de filas economicas</td>
#   </tr>
#   <tr>
#     <td class="tg-1wig">Resultado</td>
#     <td class="tg-0lax">Se crea la lista de sillas</td>
#   </tr>
#   <tr>
#     <td class="tg-1wig">Restricciones</td>
#     <td class="tg-0lax">el numero de filas tanto economicas como ejecutivas debe ser mayor a cero y deben haber mas filas economicas que ejecutivas</td>
#   </tr>
# </tbody></table>
#
#
# <style>
# .tg  {border-collapse:collapse;border-spacing:0;border-color:#aaa;}
# .tg td{font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#aaa;color:#333;background-color:#fff;}
# .tg th{font-family:Arial, sans-serif;font-size:14px;font-weight:normal;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#aaa;color:#fff;background-color:#f38630;}
# .tg .tg-1wig{font-weight:bold;text-align:left;vertical-align:top}
# .tg .tg-gcmg{font-weight:bold;background-color:#f8a102;text-align:left}
# .tg .tg-4qtd{font-weight:bold;background-color:#f8a102;text-align:left;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
#   <tbody><tr>
#     <th class="tg-gcmg">Nombre</th>
#     <th class="tg-4qtd">R2: Listar las Sillas del Avion</th>
#   </tr>
#   <tr>
#     <td class="tg-1wig">Resumen</td>
#     <td class="tg-0lax">Asigna una silla a un pasajero</td>
#   </tr>
#   <tr>
#     <td class="tg-1wig">Entradas</td>
#     <td class="tg-0lax">cedula del pasajero, </td>
#   </tr>
#   <tr>
#     <td class="tg-1wig">Resultado</td>
#     <td class="tg-0lax"></td>
#   </tr>
#   <tr>
#     <td class="tg-1wig">Restricciones</td>
#     <td class="tg-0lax">Debe haberse creado el avion</td>
#   </tr>
# </tbody></table>
#
#
# <style>
# .tg  {border-collapse:collapse;border-spacing:0;border-color:#aaa;}
# .tg td{font-family:Arial, sans-serif;font-size:14px;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#aaa;color:#333;background-color:#fff;}
# .tg th{font-family:Arial, sans-serif;font-size:14px;font-weight:normal;padding:10px 5px;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#aaa;color:#fff;background-color:#f38630;}
# .tg .tg-1wig{font-weight:bold;text-align:left;vertical-align:top}
# .tg .tg-gcmg{font-weight:bold;background-color:#f8a102;text-align:left}
# .tg .tg-4qtd{font-weight:bold;background-color:#f8a102;text-align:left;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# </style>
# <table class="tg">
#   <tbody><tr>
#     <th class="tg-gcmg">Nombre</th>
#     <th class="tg-4qtd">R3: Asignar Silla a un Pasajero</th>
#   </tr>
#   <tr>
#     <td class="tg-1wig">Resumen</td>
#     <td class="tg-0lax">Asigna una silla al pasajero de acuerdo a sus preferencias (Posicion y Tipo)</td>
#   </tr>
#   <tr>
#     <td class="tg-1wig">Entradas</td>
#     <td class="tg-0lax">cedula del pasajero, ubicacion (ventana, pasillo, centro para economica y solo ventana, pasillo para ejecutiva ) y el tipo (economica, ejecutiva)</td>
#   </tr>
#   <tr>
#     <td class="tg-1wig">Resultado</td>
#     <td class="tg-0lax">numero de silla asignada</td>
#   </tr>
#   <tr>
#     <td class="tg-1wig">Restricciones</td>
#     <td class="tg-0lax">debe ser un tipo de silla valido y una posicion valida, el documento del pasajero no puede estar vacio</td>
#   </tr>
# </tbody></table>

# %% [markdown]
# ### Estructura de Datos del avión

# %%
avion={"lista_sillas":[]}

# %%
def crearAvion(filas_ejecutiva,filas_economica):
    num_silla=1   #Cuenta el numero de sillas que se van creando
    avion["lista_sillas"].clear() # Elimina las sillas ya existentes esto es borra la lista
    
    for i in range (0,filas_ejecutiva): #Por cada fila
        silla={}
        silla["numero"]=num_silla
        silla["clase"]="Ejecutiva"
        silla["ubicacion"]="Ventana"
        silla["pasajero"]=""
        avion["lista_sillas"].append(silla)
        num_silla+=1
        
        silla={}
        silla["numero"]=num_silla
        silla["clase"]="Ejecutiva"
        silla["ubicacion"]="Pasillo"
        silla["pasajero"]=""
        avion["lista_sillas"].append(silla)
        num_silla+=1
        
        silla={}
        silla["numero"]=num_silla
        silla["clase"]="Ejecutiva"
        silla["ubicacion"]="Pasillo"
        silla["pasajero"]=""
        avion["lista_sillas"].append(silla)
        num_silla+=1

        silla={}
        silla["numero"]=num_silla
        silla["clase"]="Ejecutiva"
        silla["ubicacion"]="Ventana"
        silla["pasajero"]=""
        avion["lista_sillas"].append(silla)
        num_silla+=1

# %%
def listarSillas():
    for s in avion["lista_sillas"]: #por cada silla s en la lista de sillas del avion
        print(s,"\n") #imprime y deja una linea

# %%
def asignarSillas(documento,clase,ubicacion):
    sillaAsignada=0 #aun no se le ha asignado silla al pasajero
    indice=0 #primera posicion de la lista
    
    while indice < len(avion["lista_sillas"]) and (avion["lista_sillas"][indice]["clase"]!=clase or avion["lista_sillas"][indice]["ubicacion"]!=ubicacion or avion["lista_sillas"][indice]["pasajero"]!=""):
        indice+=1
        
    if indice < len(avion["lista_sillas"]): #encotro la silla buscada
       sillaAsignada=indice #Le asigna la silla que se encontro en la posicion indice
       avion["lista_sillas"][indice]["pasajero"]=documento #asigna el pasajero

# %%
listarSillas()
asignarSillas("1010","Ejecutiva","Ventana")
print("------------------------------------------")
listarSillas()
# Out:
# {'numero': 1, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': '1010'}
#
# {'numero': 2, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 3, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 4, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': ''}
#
# {'numero': 5, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': ''}
#
# {'numero': 6, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 7, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 8, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': ''}
#
# {'numero': 9, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': ''}
#
# {'numero': 10, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 11, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 12, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': ''}
#
# {'numero': 13, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': ''}
#
# {'numero': 14, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 15, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 16, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': ''}
#
# ------------------------------------------
# {'numero': 1, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': '1010'}
#
# {'numero': 2, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 3, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 4, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': '1010'}
#
# {'numero': 5, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': ''}
#
# {'numero': 6, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 7, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 8, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': ''}
#
# {'numero': 9, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': ''}
#
# {'numero': 10, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 11, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 12, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': ''}
#
# {'numero': 13, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': ''}
#
# {'numero': 14, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 15, 'clase': 'Ejecutiva', 'ubicacion': 'Pasillo', 'pasajero': ''}
#
# {'numero': 16, 'clase': 'Ejecutiva', 'ubicacion': 'Ventana', 'pasajero': ''}
